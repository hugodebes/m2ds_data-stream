# %%
import time

import pandas as pd
from river import (
    ensemble,
    evaluate,
    linear_model,
    metrics,
    multiclass,
    neighbors,
    preprocessing,
    stream,
    tree,
)
from tqdm.auto import tqdm

# %% [markdown]
# Columns header to add at the top of the data file:

# %%
columns_name = (
    [
        "Elevation",
        "Aspect",
        "Slope",
        "Horizontal_Distance_To_Hydrology",
        "Vertical_Distance_To_Hydrology",
        "Horizontal_Distance_To_Roadways",
        "Hillshade_9am",
        "Hillshade_Noon",
        "Hillshade_3pm",
        "Horizontal_Distance_To_Fire_Points",
    ]
    + [f"Wilderness_Area_{i}" for i in range(1, 5)]
    + [f"Soil_Type_{i}" for i in range(1, 41)]
    + ["Cover_Type"]
)

print(",".join(columns_name))
# Out:
# Elevation,Aspect,Slope,Horizontal_Distance_To_Hydrology,Vertical_Distance_To_Hydrology,Horizontal_Distance_To_Roadways,Hillshade_9am,Hillshade_Noon,Hillshade_3pm,Horizontal_Distance_To_Fire_Points,Wilderness_Area_1,Wilderness_Area_2,Wilderness_Area_3,Wilderness_Area_4,Soil_Type_1,Soil_Type_2,Soil_Type_3,Soil_Type_4,Soil_Type_5,Soil_Type_6,Soil_Type_7,Soil_Type_8,Soil_Type_9,Soil_Type_10,Soil_Type_11,Soil_Type_12,Soil_Type_13,Soil_Type_14,Soil_Type_15,Soil_Type_16,Soil_Type_17,Soil_Type_18,Soil_Type_19,Soil_Type_20,Soil_Type_21,Soil_Type_22,Soil_Type_23,Soil_Type_24,Soil_Type_25,Soil_Type_26,Soil_Type_27,Soil_Type_28,Soil_Type_29,Soil_Type_30,Soil_Type_31,Soil_Type_32,Soil_Type_33,Soil_Type_34,Soil_Type_35,Soil_Type_36,Soil_Type_37,Soil_Type_38,Soil_Type_39,Soil_Type_40,Cover_Type

# %%
N = 50_000
with open("data/covtype.data", "r") as f1:
    with open("data/covtype_small.data", "w") as f2:
        for i in range(N + 1):
            line = next(f1)
            f2.write(line)

# %%
# DATAPATH = "data/covtype.data"
# DATAKEY = "covtype"

DATAPATH = "data/covtype_small.data"
DATAKEY = "covtype_small"

# %%
with open(DATAPATH) as f:
    N_observations = sum(1 for line in f)
N_observations -= 1
print(f"Number of observations : {N_observations}")
# Out:
# Number of observations : 50000

# %%
converters = {column: int for column in columns_name}

dataset = stream.iter_csv(DATAPATH, target="Cover_Type", converters=converters)
x, y = next(iter(dataset))
x, y
# Out:
# ({'Elevation': 2596,
#   'Aspect': 51,
#   'Slope': 3,
#   'Horizontal_Distance_To_Hydrology': 258,
#   'Vertical_Distance_To_Hydrology': 0,
#   'Horizontal_Distance_To_Roadways': 510,
#   'Hillshade_9am': 221,
#   'Hillshade_Noon': 232,
#   'Hillshade_3pm': 148,
#   'Horizontal_Distance_To_Fire_Points': 6279,
#   'Wilderness_Area_1': 1,
#   'Wilderness_Area_2': 0,
#   'Wilderness_Area_3': 0,
#   'Wilderness_Area_4': 0,
#   'Soil_Type_1': 0,
#   'Soil_Type_2': 0,
#   'Soil_Type_3': 0,
#   'Soil_Type_4': 0,
#   'Soil_Type_5': 0,
#   'Soil_Type_6': 0,
#   'Soil_Type_7': 0,
#   'Soil_Type_8': 0,
#   'Soil_Type_9': 0,
#   'Soil_Type_10': 0,
#   'Soil_Type_11': 0,
#   'Soil_Type_12': 0,
#   'Soil_Type_13': 0,
#   'Soil_Type_14': 0,
#   'Soil_Type_15': 0,
#   'Soil_Type_16': 0,
#   'Soil_Type_17': 0,
#   'Soil_Type_18': 0,
#   'Soil_Type_19': 0,
#   'Soil_Type_20': 0,
#   'Soil_Type_21': 0,
#   'Soil_Type_22': 0,
#   'Soil_Type_23': 0,
#   'Soil_Type_24': 0,
#   'Soil_Type_25': 0,
#   'Soil_Type_26': 0,
#   'Soil_Type_27': 0,
#   'Soil_Type_28': 0,
#   'Soil_Type_29': 1,
#   'Soil_Type_30': 0,
#   'Soil_Type_31': 0,
#   'Soil_Type_32': 0,
#   'Soil_Type_33': 0,
#   'Soil_Type_34': 0,
#   'Soil_Type_35': 0,
#   'Soil_Type_36': 0,
#   'Soil_Type_37': 0,
#   'Soil_Type_38': 0,
#   'Soil_Type_39': 0,
#   'Soil_Type_40': 0},
#  5)

# %%
dataset = stream.iter_csv(DATAPATH, target="Cover_Type", converters=converters)
cache = stream.Cache()
cache.clear_all()

# %%
model = tree.HoeffdingTreeClassifier()
report = metrics.ClassificationReport()

for x, y in tqdm(cache(dataset, key=DATAKEY), total=N_observations):
    y_pred = model.predict_one(x)
    model.learn_one(x, y)
    if y_pred is not None:
        report.update(y, y_pred)

display(report)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
#            Precision   Recall   F1       Support
#
#        1      70.14%   43.78%   53.91%     10151
#        2      81.76%   90.53%   85.92%     28793
#        3      49.35%   38.89%   43.50%      2160
#        4      59.52%   44.72%   51.07%      2160
#        5      44.75%   38.10%   41.15%      2415
#        6      39.55%   42.59%   41.02%      2160
#        7      40.82%   76.99%   53.35%      2160
#
#    Macro      55.13%   53.66%   52.85%
#    Micro      71.64%   71.64%   71.64%
# Weighted      71.66%   71.64%   70.57%
#
#                  71.64% accuracy

# %%
model = tree.HoeffdingTreeClassifier()
report = metrics.ClassificationReport()

evaluate.progressive_val_score(cache(dataset, key=DATAKEY), model, report)
# Out:
#            Precision   Recall   F1       Support
#
#        1      70.14%   43.78%   53.91%     10151
#        2      81.76%   90.53%   85.92%     28793
#        3      49.35%   38.89%   43.50%      2160
#        4      59.52%   44.72%   51.07%      2160
#        5      44.75%   38.10%   41.15%      2415
#        6      39.55%   42.59%   41.02%      2160
#        7      40.82%   76.99%   53.35%      2160
#
#    Macro      55.13%   53.66%   52.85%
#    Micro      71.64%   71.64%   71.64%
# Weighted      71.66%   71.64%   70.57%
#
#                  71.64% accuracy

# %%
def test_model(model, model_name, df_merge=None):

    report = metrics.ClassificationReport()

    t1 = time.time()
    # evaluate.progressive_val_score(cache(dataset, key="key"), model, report)
    for x, y in tqdm(cache(dataset, key=DATAKEY), total=N_observations):
        y_pred = model.predict_one(x)
        model.learn_one(x, y)
        if y_pred is not None:
            report.update(y, y_pred)
    t2 = time.time()

    df_metrics = [
        {
            "classifier": model_name,
            "accuracy": report._accuracy.get(),
            "precision": report._weighted_precision.get(),
            "recall": report._weighted_recall.get(),
            "f1": report._weighted_f1.get(),
            "time": t2 - t1,
        }
    ]

    df_new = pd.DataFrame(df_metrics).set_index("classifier")

    if df_merge is not None:
        df_merge = pd.concat([df_merge, df_new[~df_new.index.isin(df_merge.index)]])
        df_merge.update(df_new)
        df_new = df_merge

    return df_new


def display_metrics(df_metrics):
    return df_metrics.style.background_gradient(cmap="RdYlGn").background_gradient(
        cmap="RdYlGn_r", subset=["time"]
    ).format(precision=3)

# %%
model = tree.HoeffdingTreeClassifier()

df_metrics = test_model(model, "HoeffdingTreeClassifier")
display_metrics(df_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_f9a94_row0_col0, #T_f9a94_row0_col1, #T_f9a94_row0_col2, #T_f9a94_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f9a94_row0_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f9a94">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9a94_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_f9a94_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_f9a94_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_f9a94_level0_col3" class="col_heading level0 col3" >f1</th>
#       <th id="T_f9a94_level0_col4" class="col_heading level0 col4" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9a94_level0_row0" class="row_heading level0 row0" >HoeffdingTreeClassifier</th>
#       <td id="T_f9a94_row0_col0" class="data row0 col0" >0.716</td>
#       <td id="T_f9a94_row0_col1" class="data row0 col1" >0.717</td>
#       <td id="T_f9a94_row0_col2" class="data row0 col2" >0.716</td>
#       <td id="T_f9a94_row0_col3" class="data row0 col3" >0.706</td>
#       <td id="T_f9a94_row0_col4" class="data row0 col4" >14.815</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = ensemble.AdaptiveRandomForestClassifier(seed=0)

df_metrics = test_model(model, "AdaptiveRandomForestClassifier", df_merge=df_metrics)
display_metrics(df_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_af771_row0_col0, #T_af771_row0_col1, #T_af771_row0_col2, #T_af771_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_af771_row0_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_af771_row1_col0, #T_af771_row1_col1, #T_af771_row1_col2, #T_af771_row1_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_af771_row1_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_af771">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af771_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_af771_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_af771_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_af771_level0_col3" class="col_heading level0 col3" >f1</th>
#       <th id="T_af771_level0_col4" class="col_heading level0 col4" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af771_level0_row0" class="row_heading level0 row0" >HoeffdingTreeClassifier</th>
#       <td id="T_af771_row0_col0" class="data row0 col0" >0.716</td>
#       <td id="T_af771_row0_col1" class="data row0 col1" >0.717</td>
#       <td id="T_af771_row0_col2" class="data row0 col2" >0.716</td>
#       <td id="T_af771_row0_col3" class="data row0 col3" >0.706</td>
#       <td id="T_af771_row0_col4" class="data row0 col4" >14.815</td>
#     </tr>
#     <tr>
#       <th id="T_af771_level0_row1" class="row_heading level0 row1" >AdaptiveRandomForestClassifier</th>
#       <td id="T_af771_row1_col0" class="data row1 col0" >0.862</td>
#       <td id="T_af771_row1_col1" class="data row1 col1" >0.861</td>
#       <td id="T_af771_row1_col2" class="data row1 col2" >0.862</td>
#       <td id="T_af771_row1_col3" class="data row1 col3" >0.859</td>
#       <td id="T_af771_row1_col4" class="data row1 col4" >59.609</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = ensemble.AdaBoostClassifier(
    model=(
        tree.HoeffdingTreeClassifier(
            split_criterion="gini", delta=1e-5, grace_period=2000
        )
    ),
    n_models=5,
    seed=0,
)

df_metrics = test_model(model, "AdaBoostClassifier", df_merge=df_metrics)
display_metrics(df_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_cb019_row0_col0, #T_cb019_row0_col1, #T_cb019_row0_col2, #T_cb019_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_cb019_row0_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_cb019_row1_col0, #T_cb019_row1_col1, #T_cb019_row1_col2, #T_cb019_row1_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_cb019_row1_col4 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_cb019_row2_col0, #T_cb019_row2_col2 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_cb019_row2_col1 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_cb019_row2_col3 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_cb019_row2_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cb019">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb019_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_cb019_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_cb019_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_cb019_level0_col3" class="col_heading level0 col3" >f1</th>
#       <th id="T_cb019_level0_col4" class="col_heading level0 col4" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb019_level0_row0" class="row_heading level0 row0" >HoeffdingTreeClassifier</th>
#       <td id="T_cb019_row0_col0" class="data row0 col0" >0.716</td>
#       <td id="T_cb019_row0_col1" class="data row0 col1" >0.717</td>
#       <td id="T_cb019_row0_col2" class="data row0 col2" >0.716</td>
#       <td id="T_cb019_row0_col3" class="data row0 col3" >0.706</td>
#       <td id="T_cb019_row0_col4" class="data row0 col4" >14.815</td>
#     </tr>
#     <tr>
#       <th id="T_cb019_level0_row1" class="row_heading level0 row1" >AdaptiveRandomForestClassifier</th>
#       <td id="T_cb019_row1_col0" class="data row1 col0" >0.862</td>
#       <td id="T_cb019_row1_col1" class="data row1 col1" >0.861</td>
#       <td id="T_cb019_row1_col2" class="data row1 col2" >0.862</td>
#       <td id="T_cb019_row1_col3" class="data row1 col3" >0.859</td>
#       <td id="T_cb019_row1_col4" class="data row1 col4" >59.609</td>
#     </tr>
#     <tr>
#       <th id="T_cb019_level0_row2" class="row_heading level0 row2" >AdaBoostClassifier</th>
#       <td id="T_cb019_row2_col0" class="data row2 col0" >0.763</td>
#       <td id="T_cb019_row2_col1" class="data row2 col1" >0.761</td>
#       <td id="T_cb019_row2_col2" class="data row2 col2" >0.763</td>
#       <td id="T_cb019_row2_col3" class="data row2 col3" >0.757</td>
#       <td id="T_cb019_row2_col4" class="data row2 col4" >68.802</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = neighbors.KNNClassifier(window_size=50)

df_metrics = test_model(model, "KNNClassifier_50", df_merge=df_metrics)
display_metrics(df_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_d2350_row0_col0, #T_d2350_row0_col1, #T_d2350_row0_col2, #T_d2350_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_d2350_row0_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d2350_row1_col0, #T_d2350_row1_col2 {
#   background-color: #93d168;
#   color: #000000;
# }
# #T_d2350_row1_col1 {
#   background-color: #9dd569;
#   color: #000000;
# }
# #T_d2350_row1_col3 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_d2350_row1_col4 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_d2350_row2_col0, #T_d2350_row2_col2 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_d2350_row2_col1 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_d2350_row2_col3 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_d2350_row2_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_d2350_row3_col0, #T_d2350_row3_col1, #T_d2350_row3_col2, #T_d2350_row3_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_d2350_row3_col4 {
#   background-color: #fece7c;
#   color: #000000;
#   background-color: #c7e77f;
#   color: #000000;
# }
# </style>
# <table id="T_d2350">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2350_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_d2350_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_d2350_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_d2350_level0_col3" class="col_heading level0 col3" >f1</th>
#       <th id="T_d2350_level0_col4" class="col_heading level0 col4" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2350_level0_row0" class="row_heading level0 row0" >HoeffdingTreeClassifier</th>
#       <td id="T_d2350_row0_col0" class="data row0 col0" >0.716</td>
#       <td id="T_d2350_row0_col1" class="data row0 col1" >0.717</td>
#       <td id="T_d2350_row0_col2" class="data row0 col2" >0.716</td>
#       <td id="T_d2350_row0_col3" class="data row0 col3" >0.706</td>
#       <td id="T_d2350_row0_col4" class="data row0 col4" >14.815</td>
#     </tr>
#     <tr>
#       <th id="T_d2350_level0_row1" class="row_heading level0 row1" >AdaptiveRandomForestClassifier</th>
#       <td id="T_d2350_row1_col0" class="data row1 col0" >0.862</td>
#       <td id="T_d2350_row1_col1" class="data row1 col1" >0.861</td>
#       <td id="T_d2350_row1_col2" class="data row1 col2" >0.862</td>
#       <td id="T_d2350_row1_col3" class="data row1 col3" >0.859</td>
#       <td id="T_d2350_row1_col4" class="data row1 col4" >59.609</td>
#     </tr>
#     <tr>
#       <th id="T_d2350_level0_row2" class="row_heading level0 row2" >AdaBoostClassifier</th>
#       <td id="T_d2350_row2_col0" class="data row2 col0" >0.763</td>
#       <td id="T_d2350_row2_col1" class="data row2 col1" >0.761</td>
#       <td id="T_d2350_row2_col2" class="data row2 col2" >0.763</td>
#       <td id="T_d2350_row2_col3" class="data row2 col3" >0.757</td>
#       <td id="T_d2350_row2_col4" class="data row2 col4" >68.802</td>
#     </tr>
#     <tr>
#       <th id="T_d2350_level0_row3" class="row_heading level0 row3" >KNNClassifier_50</th>
#       <td id="T_d2350_row3_col0" class="data row3 col0" >0.917</td>
#       <td id="T_d2350_row3_col1" class="data row3 col1" >0.918</td>
#       <td id="T_d2350_row3_col2" class="data row3 col2" >0.917</td>
#       <td id="T_d2350_row3_col3" class="data row3 col3" >0.917</td>
#       <td id="T_d2350_row3_col4" class="data row3 col4" >34.490</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = neighbors.KNNClassifier(window_size=100)

df_metrics = test_model(model, "KNNClassifier_100", df_merge=df_metrics)
display_metrics(df_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_81b2e_row0_col0, #T_81b2e_row0_col1, #T_81b2e_row0_col2, #T_81b2e_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_81b2e_row0_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_81b2e_row1_col0, #T_81b2e_row1_col2 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_81b2e_row1_col1 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_81b2e_row1_col3 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_81b2e_row1_col4 {
#   background-color: #4eb15d;
#   color: #f1f1f1;
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_81b2e_row2_col0, #T_81b2e_row2_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_81b2e_row2_col1 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_81b2e_row2_col3 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_81b2e_row2_col4, #T_81b2e_row4_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_81b2e_row3_col0, #T_81b2e_row3_col2, #T_81b2e_row3_col3 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_81b2e_row3_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_81b2e_row3_col4 {
#   background-color: #fece7c;
#   color: #000000;
#   background-color: #c7e77f;
#   color: #000000;
# }
# #T_81b2e_row4_col0, #T_81b2e_row4_col1, #T_81b2e_row4_col2, #T_81b2e_row4_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_81b2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81b2e_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_81b2e_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_81b2e_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_81b2e_level0_col3" class="col_heading level0 col3" >f1</th>
#       <th id="T_81b2e_level0_col4" class="col_heading level0 col4" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81b2e_level0_row0" class="row_heading level0 row0" >HoeffdingTreeClassifier</th>
#       <td id="T_81b2e_row0_col0" class="data row0 col0" >0.716</td>
#       <td id="T_81b2e_row0_col1" class="data row0 col1" >0.717</td>
#       <td id="T_81b2e_row0_col2" class="data row0 col2" >0.716</td>
#       <td id="T_81b2e_row0_col3" class="data row0 col3" >0.706</td>
#       <td id="T_81b2e_row0_col4" class="data row0 col4" >14.815</td>
#     </tr>
#     <tr>
#       <th id="T_81b2e_level0_row1" class="row_heading level0 row1" >AdaptiveRandomForestClassifier</th>
#       <td id="T_81b2e_row1_col0" class="data row1 col0" >0.862</td>
#       <td id="T_81b2e_row1_col1" class="data row1 col1" >0.861</td>
#       <td id="T_81b2e_row1_col2" class="data row1 col2" >0.862</td>
#       <td id="T_81b2e_row1_col3" class="data row1 col3" >0.859</td>
#       <td id="T_81b2e_row1_col4" class="data row1 col4" >59.609</td>
#     </tr>
#     <tr>
#       <th id="T_81b2e_level0_row2" class="row_heading level0 row2" >AdaBoostClassifier</th>
#       <td id="T_81b2e_row2_col0" class="data row2 col0" >0.763</td>
#       <td id="T_81b2e_row2_col1" class="data row2 col1" >0.761</td>
#       <td id="T_81b2e_row2_col2" class="data row2 col2" >0.763</td>
#       <td id="T_81b2e_row2_col3" class="data row2 col3" >0.757</td>
#       <td id="T_81b2e_row2_col4" class="data row2 col4" >68.802</td>
#     </tr>
#     <tr>
#       <th id="T_81b2e_level0_row3" class="row_heading level0 row3" >KNNClassifier_50</th>
#       <td id="T_81b2e_row3_col0" class="data row3 col0" >0.917</td>
#       <td id="T_81b2e_row3_col1" class="data row3 col1" >0.918</td>
#       <td id="T_81b2e_row3_col2" class="data row3 col2" >0.917</td>
#       <td id="T_81b2e_row3_col3" class="data row3 col3" >0.917</td>
#       <td id="T_81b2e_row3_col4" class="data row3 col4" >34.490</td>
#     </tr>
#     <tr>
#       <th id="T_81b2e_level0_row4" class="row_heading level0 row4" >KNNClassifier_100</th>
#       <td id="T_81b2e_row4_col0" class="data row4 col0" >0.923</td>
#       <td id="T_81b2e_row4_col1" class="data row4 col1" >0.924</td>
#       <td id="T_81b2e_row4_col2" class="data row4 col2" >0.923</td>
#       <td id="T_81b2e_row4_col3" class="data row4 col3" >0.923</td>
#       <td id="T_81b2e_row4_col4" class="data row4 col4" >68.696</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = preprocessing.StandardScaler() | multiclass.OneVsOneClassifier(
    linear_model.LogisticRegression()
)

df_metrics = test_model(model, "LogisticRegression_OVO", df_merge=df_metrics)
display_metrics(df_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_bdc88_row0_col0, #T_bdc88_row0_col1, #T_bdc88_row0_col2, #T_bdc88_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_bdc88_row0_col4 {
#   background-color: #ce2827;
#   color: #f1f1f1;
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_bdc88_row1_col0, #T_bdc88_row1_col2 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_bdc88_row1_col1 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_bdc88_row1_col3 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_bdc88_row1_col4 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_bdc88_row2_col0, #T_bdc88_row2_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_bdc88_row2_col1 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_bdc88_row2_col3 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_bdc88_row2_col4, #T_bdc88_row4_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_bdc88_row3_col0, #T_bdc88_row3_col2, #T_bdc88_row3_col3 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_bdc88_row3_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_bdc88_row3_col4 {
#   background-color: #fee593;
#   color: #000000;
#   background-color: #dff293;
#   color: #000000;
# }
# #T_bdc88_row4_col0, #T_bdc88_row4_col1, #T_bdc88_row4_col2, #T_bdc88_row4_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_bdc88_row5_col0, #T_bdc88_row5_col2 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_bdc88_row5_col1 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_bdc88_row5_col3 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_bdc88_row5_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bdc88">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdc88_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_bdc88_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_bdc88_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_bdc88_level0_col3" class="col_heading level0 col3" >f1</th>
#       <th id="T_bdc88_level0_col4" class="col_heading level0 col4" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdc88_level0_row0" class="row_heading level0 row0" >HoeffdingTreeClassifier</th>
#       <td id="T_bdc88_row0_col0" class="data row0 col0" >0.716</td>
#       <td id="T_bdc88_row0_col1" class="data row0 col1" >0.717</td>
#       <td id="T_bdc88_row0_col2" class="data row0 col2" >0.716</td>
#       <td id="T_bdc88_row0_col3" class="data row0 col3" >0.706</td>
#       <td id="T_bdc88_row0_col4" class="data row0 col4" >14.815</td>
#     </tr>
#     <tr>
#       <th id="T_bdc88_level0_row1" class="row_heading level0 row1" >AdaptiveRandomForestClassifier</th>
#       <td id="T_bdc88_row1_col0" class="data row1 col0" >0.862</td>
#       <td id="T_bdc88_row1_col1" class="data row1 col1" >0.861</td>
#       <td id="T_bdc88_row1_col2" class="data row1 col2" >0.862</td>
#       <td id="T_bdc88_row1_col3" class="data row1 col3" >0.859</td>
#       <td id="T_bdc88_row1_col4" class="data row1 col4" >59.609</td>
#     </tr>
#     <tr>
#       <th id="T_bdc88_level0_row2" class="row_heading level0 row2" >AdaBoostClassifier</th>
#       <td id="T_bdc88_row2_col0" class="data row2 col0" >0.763</td>
#       <td id="T_bdc88_row2_col1" class="data row2 col1" >0.761</td>
#       <td id="T_bdc88_row2_col2" class="data row2 col2" >0.763</td>
#       <td id="T_bdc88_row2_col3" class="data row2 col3" >0.757</td>
#       <td id="T_bdc88_row2_col4" class="data row2 col4" >68.802</td>
#     </tr>
#     <tr>
#       <th id="T_bdc88_level0_row3" class="row_heading level0 row3" >KNNClassifier_50</th>
#       <td id="T_bdc88_row3_col0" class="data row3 col0" >0.917</td>
#       <td id="T_bdc88_row3_col1" class="data row3 col1" >0.918</td>
#       <td id="T_bdc88_row3_col2" class="data row3 col2" >0.917</td>
#       <td id="T_bdc88_row3_col3" class="data row3 col3" >0.917</td>
#       <td id="T_bdc88_row3_col4" class="data row3 col4" >34.490</td>
#     </tr>
#     <tr>
#       <th id="T_bdc88_level0_row4" class="row_heading level0 row4" >KNNClassifier_100</th>
#       <td id="T_bdc88_row4_col0" class="data row4 col0" >0.923</td>
#       <td id="T_bdc88_row4_col1" class="data row4 col1" >0.924</td>
#       <td id="T_bdc88_row4_col2" class="data row4 col2" >0.923</td>
#       <td id="T_bdc88_row4_col3" class="data row4 col3" >0.923</td>
#       <td id="T_bdc88_row4_col4" class="data row4 col4" >68.696</td>
#     </tr>
#     <tr>
#       <th id="T_bdc88_level0_row5" class="row_heading level0 row5" >LogisticRegression_OVO</th>
#       <td id="T_bdc88_row5_col0" class="data row5 col0" >0.852</td>
#       <td id="T_bdc88_row5_col1" class="data row5 col1" >0.850</td>
#       <td id="T_bdc88_row5_col2" class="data row5 col2" >0.852</td>
#       <td id="T_bdc88_row5_col3" class="data row5 col3" >0.849</td>
#       <td id="T_bdc88_row5_col4" class="data row5 col4" >9.902</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = preprocessing.StandardScaler() | multiclass.OneVsRestClassifier(
    linear_model.LogisticRegression()
)

df_metrics = test_model(model, "LogisticRegression_OVR", df_merge=df_metrics)
display_metrics(df_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_7b12f_row0_col0, #T_7b12f_row0_col1, #T_7b12f_row0_col2, #T_7b12f_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_7b12f_row0_col4 {
#   background-color: #d62f27;
#   color: #f1f1f1;
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_7b12f_row1_col0, #T_7b12f_row1_col2 {
#   background-color: #a0d669;
#   color: #000000;
# }
# #T_7b12f_row1_col1 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_7b12f_row1_col3 {
#   background-color: #a2d76a;
#   color: #000000;
# }
# #T_7b12f_row1_col4 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
#   background-color: #e65036;
#   color: #f1f1f1;
# }
# #T_7b12f_row2_col0, #T_7b12f_row2_col2 {
#   background-color: #f67c4a;
#   color: #f1f1f1;
# }
# #T_7b12f_row2_col1 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_7b12f_row2_col3 {
#   background-color: #f7844e;
#   color: #f1f1f1;
# }
# #T_7b12f_row2_col4, #T_7b12f_row4_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_7b12f_row3_col0, #T_7b12f_row3_col2, #T_7b12f_row3_col3 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_7b12f_row3_col1 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_7b12f_row3_col4 {
#   background-color: #fee999;
#   color: #000000;
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_7b12f_row4_col0, #T_7b12f_row4_col1, #T_7b12f_row4_col2, #T_7b12f_row4_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_7b12f_row5_col0, #T_7b12f_row5_col2, #T_7b12f_row6_col3 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_7b12f_row5_col1 {
#   background-color: #c3e67d;
#   color: #000000;
# }
# #T_7b12f_row5_col3 {
#   background-color: #b9e176;
#   color: #000000;
# }
# #T_7b12f_row5_col4 {
#   background-color: #ad0826;
#   color: #f1f1f1;
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_7b12f_row6_col0, #T_7b12f_row6_col2 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_7b12f_row6_col1 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_7b12f_row6_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7b12f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b12f_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_7b12f_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_7b12f_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_7b12f_level0_col3" class="col_heading level0 col3" >f1</th>
#       <th id="T_7b12f_level0_col4" class="col_heading level0 col4" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b12f_level0_row0" class="row_heading level0 row0" >HoeffdingTreeClassifier</th>
#       <td id="T_7b12f_row0_col0" class="data row0 col0" >0.716</td>
#       <td id="T_7b12f_row0_col1" class="data row0 col1" >0.717</td>
#       <td id="T_7b12f_row0_col2" class="data row0 col2" >0.716</td>
#       <td id="T_7b12f_row0_col3" class="data row0 col3" >0.706</td>
#       <td id="T_7b12f_row0_col4" class="data row0 col4" >14.815</td>
#     </tr>
#     <tr>
#       <th id="T_7b12f_level0_row1" class="row_heading level0 row1" >AdaptiveRandomForestClassifier</th>
#       <td id="T_7b12f_row1_col0" class="data row1 col0" >0.862</td>
#       <td id="T_7b12f_row1_col1" class="data row1 col1" >0.861</td>
#       <td id="T_7b12f_row1_col2" class="data row1 col2" >0.862</td>
#       <td id="T_7b12f_row1_col3" class="data row1 col3" >0.859</td>
#       <td id="T_7b12f_row1_col4" class="data row1 col4" >59.609</td>
#     </tr>
#     <tr>
#       <th id="T_7b12f_level0_row2" class="row_heading level0 row2" >AdaBoostClassifier</th>
#       <td id="T_7b12f_row2_col0" class="data row2 col0" >0.763</td>
#       <td id="T_7b12f_row2_col1" class="data row2 col1" >0.761</td>
#       <td id="T_7b12f_row2_col2" class="data row2 col2" >0.763</td>
#       <td id="T_7b12f_row2_col3" class="data row2 col3" >0.757</td>
#       <td id="T_7b12f_row2_col4" class="data row2 col4" >68.802</td>
#     </tr>
#     <tr>
#       <th id="T_7b12f_level0_row3" class="row_heading level0 row3" >KNNClassifier_50</th>
#       <td id="T_7b12f_row3_col0" class="data row3 col0" >0.917</td>
#       <td id="T_7b12f_row3_col1" class="data row3 col1" >0.918</td>
#       <td id="T_7b12f_row3_col2" class="data row3 col2" >0.917</td>
#       <td id="T_7b12f_row3_col3" class="data row3 col3" >0.917</td>
#       <td id="T_7b12f_row3_col4" class="data row3 col4" >34.490</td>
#     </tr>
#     <tr>
#       <th id="T_7b12f_level0_row4" class="row_heading level0 row4" >KNNClassifier_100</th>
#       <td id="T_7b12f_row4_col0" class="data row4 col0" >0.923</td>
#       <td id="T_7b12f_row4_col1" class="data row4 col1" >0.924</td>
#       <td id="T_7b12f_row4_col2" class="data row4 col2" >0.923</td>
#       <td id="T_7b12f_row4_col3" class="data row4 col3" >0.923</td>
#       <td id="T_7b12f_row4_col4" class="data row4 col4" >68.696</td>
#     </tr>
#     <tr>
#       <th id="T_7b12f_level0_row5" class="row_heading level0 row5" >LogisticRegression_OVO</th>
#       <td id="T_7b12f_row5_col0" class="data row5 col0" >0.852</td>
#       <td id="T_7b12f_row5_col1" class="data row5 col1" >0.850</td>
#       <td id="T_7b12f_row5_col2" class="data row5 col2" >0.852</td>
#       <td id="T_7b12f_row5_col3" class="data row5 col3" >0.849</td>
#       <td id="T_7b12f_row5_col4" class="data row5 col4" >9.902</td>
#     </tr>
#     <tr>
#       <th id="T_7b12f_level0_row6" class="row_heading level0 row6" >LogisticRegression_OVR</th>
#       <td id="T_7b12f_row6_col0" class="data row6 col0" >0.851</td>
#       <td id="T_7b12f_row6_col1" class="data row6 col1" >0.849</td>
#       <td id="T_7b12f_row6_col2" class="data row6 col2" >0.851</td>
#       <td id="T_7b12f_row6_col3" class="data row6 col3" >0.849</td>
#       <td id="T_7b12f_row6_col4" class="data row6 col4" >8.914</td>
#     </tr>
#   </tbody>
# </table>

# %%
cache.clear_all()
