# %% [markdown]
# # Covtype dataset

# %%
import time

import pandas as pd
from river import (
    ensemble,
    evaluate,
    linear_model,
    metrics,
    multiclass,
    neighbors,
    preprocessing,
    stream,
    tree,
    utils,
)
from tqdm.auto import tqdm

import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
from matplotlib.ticker import AutoMinorLocator

# %% [markdown]
# Columns header to add at the top of the data file:

# %%
columns_name = (
    [
        "Elevation",
        "Aspect",
        "Slope",
        "Horizontal_Distance_To_Hydrology",
        "Vertical_Distance_To_Hydrology",
        "Horizontal_Distance_To_Roadways",
        "Hillshade_9am",
        "Hillshade_Noon",
        "Hillshade_3pm",
        "Horizontal_Distance_To_Fire_Points",
    ]
    + [f"Wilderness_Area_{i}" for i in range(1, 5)]
    + [f"Soil_Type_{i}" for i in range(1, 41)]
    + ["Cover_Type"]
)

print(",".join(columns_name))
# Out:
# Elevation,Aspect,Slope,Horizontal_Distance_To_Hydrology,Vertical_Distance_To_Hydrology,Horizontal_Distance_To_Roadways,Hillshade_9am,Hillshade_Noon,Hillshade_3pm,Horizontal_Distance_To_Fire_Points,Wilderness_Area_1,Wilderness_Area_2,Wilderness_Area_3,Wilderness_Area_4,Soil_Type_1,Soil_Type_2,Soil_Type_3,Soil_Type_4,Soil_Type_5,Soil_Type_6,Soil_Type_7,Soil_Type_8,Soil_Type_9,Soil_Type_10,Soil_Type_11,Soil_Type_12,Soil_Type_13,Soil_Type_14,Soil_Type_15,Soil_Type_16,Soil_Type_17,Soil_Type_18,Soil_Type_19,Soil_Type_20,Soil_Type_21,Soil_Type_22,Soil_Type_23,Soil_Type_24,Soil_Type_25,Soil_Type_26,Soil_Type_27,Soil_Type_28,Soil_Type_29,Soil_Type_30,Soil_Type_31,Soil_Type_32,Soil_Type_33,Soil_Type_34,Soil_Type_35,Soil_Type_36,Soil_Type_37,Soil_Type_38,Soil_Type_39,Soil_Type_40,Cover_Type

# %%
N = 50_000
with open("data/covtype.data", "r") as f1:
    with open("data/covtype_small.data", "w") as f2:
        for i in range(N + 1):
            line = next(f1)
            f2.write(line)

# %%
DATAPATH = "data/covtype_small.data"
DATAKEY = "covtype_small"

# %%
with open(DATAPATH) as f:
    N_observations = sum(1 for line in f)
N_observations -= 1
print(f"Number of observations : {N_observations}")
# Out:
# Number of observations : 50000

# %%
converters = {column: int for column in columns_name}

dataset = stream.iter_csv(DATAPATH, target="Cover_Type", converters=converters)
x, y = next(iter(dataset))
x, y
# Out:
# ({'Elevation': 2596,
#   'Aspect': 51,
#   'Slope': 3,
#   'Horizontal_Distance_To_Hydrology': 258,
#   'Vertical_Distance_To_Hydrology': 0,
#   'Horizontal_Distance_To_Roadways': 510,
#   'Hillshade_9am': 221,
#   'Hillshade_Noon': 232,
#   'Hillshade_3pm': 148,
#   'Horizontal_Distance_To_Fire_Points': 6279,
#   'Wilderness_Area_1': 1,
#   'Wilderness_Area_2': 0,
#   'Wilderness_Area_3': 0,
#   'Wilderness_Area_4': 0,
#   'Soil_Type_1': 0,
#   'Soil_Type_2': 0,
#   'Soil_Type_3': 0,
#   'Soil_Type_4': 0,
#   'Soil_Type_5': 0,
#   'Soil_Type_6': 0,
#   'Soil_Type_7': 0,
#   'Soil_Type_8': 0,
#   'Soil_Type_9': 0,
#   'Soil_Type_10': 0,
#   'Soil_Type_11': 0,
#   'Soil_Type_12': 0,
#   'Soil_Type_13': 0,
#   'Soil_Type_14': 0,
#   'Soil_Type_15': 0,
#   'Soil_Type_16': 0,
#   'Soil_Type_17': 0,
#   'Soil_Type_18': 0,
#   'Soil_Type_19': 0,
#   'Soil_Type_20': 0,
#   'Soil_Type_21': 0,
#   'Soil_Type_22': 0,
#   'Soil_Type_23': 0,
#   'Soil_Type_24': 0,
#   'Soil_Type_25': 0,
#   'Soil_Type_26': 0,
#   'Soil_Type_27': 0,
#   'Soil_Type_28': 0,
#   'Soil_Type_29': 1,
#   'Soil_Type_30': 0,
#   'Soil_Type_31': 0,
#   'Soil_Type_32': 0,
#   'Soil_Type_33': 0,
#   'Soil_Type_34': 0,
#   'Soil_Type_35': 0,
#   'Soil_Type_36': 0,
#   'Soil_Type_37': 0,
#   'Soil_Type_38': 0,
#   'Soil_Type_39': 0,
#   'Soil_Type_40': 0},
#  5)

# %%
dataset = stream.iter_csv(DATAPATH, target="Cover_Type", converters=converters)
cache = stream.Cache()
cache.clear_all()

# %%
model = tree.HoeffdingTreeClassifier()
report = metrics.ClassificationReport()

for x, y in tqdm(cache(dataset, key=DATAKEY), total=N_observations):
    y_pred = model.predict_one(x)
    model.learn_one(x, y)
    if y_pred is not None:
        report.update(y, y_pred)

display(report)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
#            Precision   Recall   F1       Support
#
#        1      70.14%   43.78%   53.91%     10151
#        2      81.76%   90.53%   85.92%     28793
#        3      49.35%   38.89%   43.50%      2160
#        4      59.52%   44.72%   51.07%      2160
#        5      44.75%   38.10%   41.15%      2415
#        6      39.55%   42.59%   41.02%      2160
#        7      40.82%   76.99%   53.35%      2160
#
#    Macro      55.13%   53.66%   52.85%
#    Micro      71.64%   71.64%   71.64%
# Weighted      71.66%   71.64%   70.57%
#
#                  71.64% accuracy

# %%
model = tree.HoeffdingTreeClassifier()
report = metrics.ClassificationReport()

evaluate.progressive_val_score(cache(dataset, key=DATAKEY), model, report)
# Out:
#            Precision   Recall   F1       Support
#
#        1      70.14%   43.78%   53.91%     10151
#        2      81.76%   90.53%   85.92%     28793
#        3      49.35%   38.89%   43.50%      2160
#        4      59.52%   44.72%   51.07%      2160
#        5      44.75%   38.10%   41.15%      2415
#        6      39.55%   42.59%   41.02%      2160
#        7      40.82%   76.99%   53.35%      2160
#
#    Macro      55.13%   53.66%   52.85%
#    Micro      71.64%   71.64%   71.64%
# Weighted      71.66%   71.64%   70.57%
#
#                  71.64% accuracy

# %%
def test_model(
    model, model_name, n_wait=1000, old_df_final_metrics=None, old_df_all_metrics=None
):

    # Define metrics
    acc = metrics.Accuracy()
    acc_roll = utils.Rolling(metrics.Accuracy(), window_size=n_wait)
    balanced_acc = metrics.BalancedAccuracy()
    balanced_acc_roll = utils.Rolling(metrics.BalancedAccuracy(), window_size=n_wait)
    f1 = metrics.WeightedF1()
    f1_roll = utils.Rolling(metrics.WeightedF1(), window_size=n_wait)
    # report = metrics.ClassificationReport()
    # report_rolling = utils.Rolling(metrics.ClassificationReport(), window_size=n_wait)

    raw_metrics = []

    t1 = time.time()
    # evaluate.progressive_val_score(cache(dataset, key="key"), model, report)
    for i, (x, y) in tqdm(enumerate(cache(dataset, key=DATAKEY)), total=N_observations):
        # Predict
        y_pred = model.predict_one(x)
        # Update metrics and results
        # if y_pred is not None:
        acc.update(y, y_pred)
        acc_roll.update(y, y_pred)
        balanced_acc.update(y, y_pred)
        balanced_acc_roll.update(y, y_pred)
        f1.update(y, y_pred)
        f1_roll.update(y, y_pred)
        # report.update(y, y_pred)
        # report_rolling.update(y, y_pred)
        if i % n_wait == 0 and i > 0:
            raw_metrics.append(
                [
                    model_name,
                    i,
                    acc.get(),
                    balanced_acc.get(),
                    f1.get(),
                    acc_roll.get(),
                    balanced_acc_roll.get(),
                    f1_roll.get(),
                ]
            )
        # Learn
        model.learn_one(x, y)
    t2 = time.time()

    df_final_metrics = [
        {
            "classifier": model_name,
            "accuracy": acc.get(),
            "balanced_accuracy": balanced_acc.get(),
            "weighted_f1": f1.get(),
            "time": t2 - t1,
        }
    ]
    df_final_metrics = pd.DataFrame(df_final_metrics).set_index("classifier")

    if old_df_final_metrics is not None:
        df_merge_final_metrics = pd.concat(
            [
                old_df_final_metrics,
                df_final_metrics[
                    ~df_final_metrics.index.isin(old_df_final_metrics.index)
                ],
            ]
        )
        df_merge_final_metrics.update(df_final_metrics)
        df_final_metrics = df_merge_final_metrics

    df_all_metrics = pd.DataFrame(
        raw_metrics,
        columns=[
            "classifier",
            "id",
            "accuracy",
            "balanced_accuracy",
            "weighted_f1",
            "accuracy_roll",
            "balanced_accuracy_roll",
            "weighted_f1_roll",
        ],
    ).set_index(["classifier", "id"])

    if old_df_all_metrics is not None:
        df_merge_all_metrics = pd.concat(
            [
                old_df_all_metrics,
                df_all_metrics[~df_all_metrics.index.isin(old_df_all_metrics.index)],
            ]
        )
        df_merge_all_metrics.update(df_all_metrics)
        df_all_metrics = df_merge_all_metrics

    return df_final_metrics, df_all_metrics


def display_metrics(df_metrics):
    return (
        df_metrics.style.background_gradient(cmap="RdYlGn")
        .background_gradient(cmap="RdYlGn_r", subset=["time"])
        .format(precision=3)
    )

# %% [markdown]
# ## 1. HoeffdingTreeClassifier

# %%
model = tree.HoeffdingTreeClassifier()

df_final_metrics, df_all_metrics = test_model(model, "HoeffdingTreeClassifier")
display_metrics(df_final_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_19b9f_row0_col0, #T_19b9f_row0_col1, #T_19b9f_row0_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_19b9f_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_19b9f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19b9f_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_19b9f_level0_col1" class="col_heading level0 col1" >balanced_accuracy</th>
#       <th id="T_19b9f_level0_col2" class="col_heading level0 col2" >weighted_f1</th>
#       <th id="T_19b9f_level0_col3" class="col_heading level0 col3" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19b9f_level0_row0" class="row_heading level0 row0" >HoeffdingTreeClassifier</th>
#       <td id="T_19b9f_row0_col0" class="data row0 col0" >0.716</td>
#       <td id="T_19b9f_row0_col1" class="data row0 col1" >0.469</td>
#       <td id="T_19b9f_row0_col2" class="data row0 col2" >0.706</td>
#       <td id="T_19b9f_row0_col3" class="data row0 col3" >15.480</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 2. AdaptiveRandomForestClassifier

# %%
model = ensemble.AdaptiveRandomForestClassifier(seed=0)

df_final_metrics, df_all_metrics = test_model(
    model,
    "AdaptiveRandomForestClassifier",
    old_df_final_metrics=df_final_metrics,
    old_df_all_metrics=df_all_metrics,
)
display_metrics(df_final_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_e94ba_row0_col0, #T_e94ba_row0_col1, #T_e94ba_row0_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_e94ba_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e94ba_row1_col0, #T_e94ba_row1_col1, #T_e94ba_row1_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_e94ba_row1_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e94ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e94ba_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_e94ba_level0_col1" class="col_heading level0 col1" >balanced_accuracy</th>
#       <th id="T_e94ba_level0_col2" class="col_heading level0 col2" >weighted_f1</th>
#       <th id="T_e94ba_level0_col3" class="col_heading level0 col3" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e94ba_level0_row0" class="row_heading level0 row0" >HoeffdingTreeClassifier</th>
#       <td id="T_e94ba_row0_col0" class="data row0 col0" >0.716</td>
#       <td id="T_e94ba_row0_col1" class="data row0 col1" >0.469</td>
#       <td id="T_e94ba_row0_col2" class="data row0 col2" >0.706</td>
#       <td id="T_e94ba_row0_col3" class="data row0 col3" >15.480</td>
#     </tr>
#     <tr>
#       <th id="T_e94ba_level0_row1" class="row_heading level0 row1" >AdaptiveRandomForestClassifier</th>
#       <td id="T_e94ba_row1_col0" class="data row1 col0" >0.862</td>
#       <td id="T_e94ba_row1_col1" class="data row1 col1" >0.686</td>
#       <td id="T_e94ba_row1_col2" class="data row1 col2" >0.859</td>
#       <td id="T_e94ba_row1_col3" class="data row1 col3" >60.212</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3. AdaBoostClassifier

# %%
model = ensemble.AdaBoostClassifier(
    model=(
        tree.HoeffdingTreeClassifier(
            split_criterion="gini", delta=1e-5, grace_period=2000
        )
    ),
    n_models=5,
    seed=0,
)

df_final_metrics, df_all_metrics = test_model(
    model,
    "AdaBoostClassifier",
    old_df_final_metrics=df_final_metrics,
    old_df_all_metrics=df_all_metrics,
)
display_metrics(df_final_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_792ab_row0_col0, #T_792ab_row0_col1, #T_792ab_row0_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_792ab_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_792ab_row1_col0, #T_792ab_row1_col1, #T_792ab_row1_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_792ab_row1_col3 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_792ab_row2_col0 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_792ab_row2_col1 {
#   background-color: #e75337;
#   color: #f1f1f1;
# }
# #T_792ab_row2_col2 {
#   background-color: #fdbf6f;
#   color: #000000;
# }
# #T_792ab_row2_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_792ab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_792ab_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_792ab_level0_col1" class="col_heading level0 col1" >balanced_accuracy</th>
#       <th id="T_792ab_level0_col2" class="col_heading level0 col2" >weighted_f1</th>
#       <th id="T_792ab_level0_col3" class="col_heading level0 col3" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_792ab_level0_row0" class="row_heading level0 row0" >HoeffdingTreeClassifier</th>
#       <td id="T_792ab_row0_col0" class="data row0 col0" >0.716</td>
#       <td id="T_792ab_row0_col1" class="data row0 col1" >0.469</td>
#       <td id="T_792ab_row0_col2" class="data row0 col2" >0.706</td>
#       <td id="T_792ab_row0_col3" class="data row0 col3" >15.480</td>
#     </tr>
#     <tr>
#       <th id="T_792ab_level0_row1" class="row_heading level0 row1" >AdaptiveRandomForestClassifier</th>
#       <td id="T_792ab_row1_col0" class="data row1 col0" >0.862</td>
#       <td id="T_792ab_row1_col1" class="data row1 col1" >0.686</td>
#       <td id="T_792ab_row1_col2" class="data row1 col2" >0.859</td>
#       <td id="T_792ab_row1_col3" class="data row1 col3" >60.212</td>
#     </tr>
#     <tr>
#       <th id="T_792ab_level0_row2" class="row_heading level0 row2" >AdaBoostClassifier</th>
#       <td id="T_792ab_row2_col0" class="data row2 col0" >0.763</td>
#       <td id="T_792ab_row2_col1" class="data row2 col1" >0.504</td>
#       <td id="T_792ab_row2_col2" class="data row2 col2" >0.757</td>
#       <td id="T_792ab_row2_col3" class="data row2 col3" >68.836</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 4. KNNClassifier

# %%
knn_df_final_metrics, knn_df_all_metrics = None, None

for window_size in [25, 50, 100]:
    model = neighbors.KNNClassifier(window_size=window_size)
    knn_df_final_metrics, knn_df_all_metrics = test_model(
        model,
        f"KNNClassifier_{window_size}",
        old_df_final_metrics=knn_df_final_metrics,
        old_df_all_metrics=knn_df_all_metrics,
    )
display_metrics(knn_df_final_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
#   0%|          | 0/50000 [00:00<?, ?it/s]
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_78821_row0_col0, #T_78821_row0_col1, #T_78821_row0_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_78821_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_78821_row1_col0 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_78821_row1_col1 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_78821_row1_col2 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_78821_row1_col3 {
#   background-color: #fdbd6d;
#   color: #000000;
#   background-color: #b5df74;
#   color: #000000;
# }
# #T_78821_row2_col0, #T_78821_row2_col1, #T_78821_row2_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_78821_row2_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_78821">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78821_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_78821_level0_col1" class="col_heading level0 col1" >balanced_accuracy</th>
#       <th id="T_78821_level0_col2" class="col_heading level0 col2" >weighted_f1</th>
#       <th id="T_78821_level0_col3" class="col_heading level0 col3" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78821_level0_row0" class="row_heading level0 row0" >KNNClassifier_25</th>
#       <td id="T_78821_row0_col0" class="data row0 col0" >0.901</td>
#       <td id="T_78821_row0_col1" class="data row0 col1" >0.725</td>
#       <td id="T_78821_row0_col2" class="data row0 col2" >0.902</td>
#       <td id="T_78821_row0_col3" class="data row0 col3" >17.831</td>
#     </tr>
#     <tr>
#       <th id="T_78821_level0_row1" class="row_heading level0 row1" >KNNClassifier_50</th>
#       <td id="T_78821_row1_col0" class="data row1 col0" >0.917</td>
#       <td id="T_78821_row1_col1" class="data row1 col1" >0.761</td>
#       <td id="T_78821_row1_col2" class="data row1 col2" >0.917</td>
#       <td id="T_78821_row1_col3" class="data row1 col3" >34.470</td>
#     </tr>
#     <tr>
#       <th id="T_78821_level0_row2" class="row_heading level0 row2" >KNNClassifier_100</th>
#       <td id="T_78821_row2_col0" class="data row2 col0" >0.923</td>
#       <td id="T_78821_row2_col1" class="data row2 col1" >0.773</td>
#       <td id="T_78821_row2_col2" class="data row2 col2" >0.923</td>
#       <td id="T_78821_row2_col3" class="data row2 col3" >67.957</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = neighbors.KNNClassifier(window_size=25)

df_final_metrics, df_all_metrics = test_model(
    model,
    "KNNClassifier",
    old_df_final_metrics=df_final_metrics,
    old_df_all_metrics=df_all_metrics,
)
display_metrics(df_final_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_9c10a_row0_col0, #T_9c10a_row0_col1, #T_9c10a_row0_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_9c10a_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_9c10a_row1_col0 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_9c10a_row1_col1 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_9c10a_row1_col2 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_9c10a_row1_col3 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
#   background-color: #e95538;
#   color: #f1f1f1;
# }
# #T_9c10a_row2_col0 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_9c10a_row2_col1 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_9c10a_row2_col2 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_9c10a_row2_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_9c10a_row3_col0, #T_9c10a_row3_col1, #T_9c10a_row3_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_9c10a_row3_col3 {
#   background-color: #bd1726;
#   color: #f1f1f1;
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9c10a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c10a_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_9c10a_level0_col1" class="col_heading level0 col1" >balanced_accuracy</th>
#       <th id="T_9c10a_level0_col2" class="col_heading level0 col2" >weighted_f1</th>
#       <th id="T_9c10a_level0_col3" class="col_heading level0 col3" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c10a_level0_row0" class="row_heading level0 row0" >HoeffdingTreeClassifier</th>
#       <td id="T_9c10a_row0_col0" class="data row0 col0" >0.716</td>
#       <td id="T_9c10a_row0_col1" class="data row0 col1" >0.469</td>
#       <td id="T_9c10a_row0_col2" class="data row0 col2" >0.706</td>
#       <td id="T_9c10a_row0_col3" class="data row0 col3" >15.480</td>
#     </tr>
#     <tr>
#       <th id="T_9c10a_level0_row1" class="row_heading level0 row1" >AdaptiveRandomForestClassifier</th>
#       <td id="T_9c10a_row1_col0" class="data row1 col0" >0.862</td>
#       <td id="T_9c10a_row1_col1" class="data row1 col1" >0.686</td>
#       <td id="T_9c10a_row1_col2" class="data row1 col2" >0.859</td>
#       <td id="T_9c10a_row1_col3" class="data row1 col3" >60.212</td>
#     </tr>
#     <tr>
#       <th id="T_9c10a_level0_row2" class="row_heading level0 row2" >AdaBoostClassifier</th>
#       <td id="T_9c10a_row2_col0" class="data row2 col0" >0.763</td>
#       <td id="T_9c10a_row2_col1" class="data row2 col1" >0.504</td>
#       <td id="T_9c10a_row2_col2" class="data row2 col2" >0.757</td>
#       <td id="T_9c10a_row2_col3" class="data row2 col3" >68.836</td>
#     </tr>
#     <tr>
#       <th id="T_9c10a_level0_row3" class="row_heading level0 row3" >KNNClassifier</th>
#       <td id="T_9c10a_row3_col0" class="data row3 col0" >0.901</td>
#       <td id="T_9c10a_row3_col1" class="data row3 col1" >0.725</td>
#       <td id="T_9c10a_row3_col2" class="data row3 col2" >0.902</td>
#       <td id="T_9c10a_row3_col3" class="data row3 col3" >18.054</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 5. LogisticRegression

# %%
lr_df_final_metrics, lr_df_all_metrics = None, None

model = preprocessing.StandardScaler() | multiclass.OneVsOneClassifier(
    linear_model.LogisticRegression()
)
lr_df_final_metrics, lr_df_all_metrics = test_model(
    model,
    "LogisticRegression_OVO",
    old_df_final_metrics=lr_df_final_metrics,
    old_df_all_metrics=lr_df_all_metrics,
)

model = preprocessing.StandardScaler() | multiclass.OneVsRestClassifier(
    linear_model.LogisticRegression()
)
lr_df_final_metrics, lr_df_all_metrics = test_model(
    model,
    "LogisticRegression_OVR",
    old_df_final_metrics=lr_df_final_metrics,
    old_df_all_metrics=lr_df_all_metrics,
)

display_metrics(lr_df_final_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_f8465_row0_col0, #T_f8465_row0_col1, #T_f8465_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_f8465_row0_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f8465_row1_col0, #T_f8465_row1_col1, #T_f8465_row1_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_f8465_row1_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f8465">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8465_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_f8465_level0_col1" class="col_heading level0 col1" >balanced_accuracy</th>
#       <th id="T_f8465_level0_col2" class="col_heading level0 col2" >weighted_f1</th>
#       <th id="T_f8465_level0_col3" class="col_heading level0 col3" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8465_level0_row0" class="row_heading level0 row0" >LogisticRegression_OVO</th>
#       <td id="T_f8465_row0_col0" class="data row0 col0" >0.852</td>
#       <td id="T_f8465_row0_col1" class="data row0 col1" >0.684</td>
#       <td id="T_f8465_row0_col2" class="data row0 col2" >0.849</td>
#       <td id="T_f8465_row0_col3" class="data row0 col3" >10.330</td>
#     </tr>
#     <tr>
#       <th id="T_f8465_level0_row1" class="row_heading level0 row1" >LogisticRegression_OVR</th>
#       <td id="T_f8465_row1_col0" class="data row1 col0" >0.851</td>
#       <td id="T_f8465_row1_col1" class="data row1 col1" >0.683</td>
#       <td id="T_f8465_row1_col2" class="data row1 col2" >0.849</td>
#       <td id="T_f8465_row1_col3" class="data row1 col3" >8.983</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = preprocessing.StandardScaler() | multiclass.OneVsOneClassifier(
    linear_model.LogisticRegression()
)

df_final_metrics, df_all_metrics = test_model(
    model,
    "LogisticRegression",
    old_df_final_metrics=df_final_metrics,
    old_df_all_metrics=df_all_metrics,
)
display_metrics(df_final_metrics)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
# <style type="text/css">
# #T_156ea_row0_col0, #T_156ea_row0_col1, #T_156ea_row0_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_156ea_row0_col3 {
#   background-color: #ce2827;
#   color: #f1f1f1;
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_156ea_row1_col0 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_156ea_row1_col1 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_156ea_row1_col2 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_156ea_row1_col3 {
#   background-color: #3ca959;
#   color: #f1f1f1;
#   background-color: #e44c34;
#   color: #f1f1f1;
# }
# #T_156ea_row2_col0 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_156ea_row2_col1 {
#   background-color: #e14430;
#   color: #f1f1f1;
# }
# #T_156ea_row2_col2 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_156ea_row2_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_156ea_row3_col0, #T_156ea_row3_col1, #T_156ea_row3_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_156ea_row3_col3 {
#   background-color: #de402e;
#   color: #f1f1f1;
#   background-color: #2da155;
#   color: #f1f1f1;
# }
# #T_156ea_row4_col0 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_156ea_row4_col1 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_156ea_row4_col2 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_156ea_row4_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_156ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_156ea_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_156ea_level0_col1" class="col_heading level0 col1" >balanced_accuracy</th>
#       <th id="T_156ea_level0_col2" class="col_heading level0 col2" >weighted_f1</th>
#       <th id="T_156ea_level0_col3" class="col_heading level0 col3" >time</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >classifier</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_156ea_level0_row0" class="row_heading level0 row0" >HoeffdingTreeClassifier</th>
#       <td id="T_156ea_row0_col0" class="data row0 col0" >0.716</td>
#       <td id="T_156ea_row0_col1" class="data row0 col1" >0.469</td>
#       <td id="T_156ea_row0_col2" class="data row0 col2" >0.706</td>
#       <td id="T_156ea_row0_col3" class="data row0 col3" >15.480</td>
#     </tr>
#     <tr>
#       <th id="T_156ea_level0_row1" class="row_heading level0 row1" >AdaptiveRandomForestClassifier</th>
#       <td id="T_156ea_row1_col0" class="data row1 col0" >0.862</td>
#       <td id="T_156ea_row1_col1" class="data row1 col1" >0.686</td>
#       <td id="T_156ea_row1_col2" class="data row1 col2" >0.859</td>
#       <td id="T_156ea_row1_col3" class="data row1 col3" >60.212</td>
#     </tr>
#     <tr>
#       <th id="T_156ea_level0_row2" class="row_heading level0 row2" >AdaBoostClassifier</th>
#       <td id="T_156ea_row2_col0" class="data row2 col0" >0.763</td>
#       <td id="T_156ea_row2_col1" class="data row2 col1" >0.504</td>
#       <td id="T_156ea_row2_col2" class="data row2 col2" >0.757</td>
#       <td id="T_156ea_row2_col3" class="data row2 col3" >68.836</td>
#     </tr>
#     <tr>
#       <th id="T_156ea_level0_row3" class="row_heading level0 row3" >KNNClassifier</th>
#       <td id="T_156ea_row3_col0" class="data row3 col0" >0.901</td>
#       <td id="T_156ea_row3_col1" class="data row3 col1" >0.725</td>
#       <td id="T_156ea_row3_col2" class="data row3 col2" >0.902</td>
#       <td id="T_156ea_row3_col3" class="data row3 col3" >18.054</td>
#     </tr>
#     <tr>
#       <th id="T_156ea_level0_row4" class="row_heading level0 row4" >LogisticRegression</th>
#       <td id="T_156ea_row4_col0" class="data row4 col0" >0.852</td>
#       <td id="T_156ea_row4_col1" class="data row4 col1" >0.684</td>
#       <td id="T_156ea_row4_col2" class="data row4 col2" >0.849</td>
#       <td id="T_156ea_row4_col3" class="data row4 col3" >10.548</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6. Plots

# %%
grouped = df_all_metrics.reset_index().set_index("id").groupby("classifier")

for METRIC in ["accuracy", "balanced_accuracy", "weighted_f1"]:
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5), sharey=True)
    for metric, ax in zip([METRIC, METRIC + "_roll"], axes.flatten()):
        grouped[metric].plot(rot=45, title=metric, legend=True, ax=ax)

        ax.legend(loc="lower right")
        ax.set_ylim(0, 1)
        ax.set_xlim(0, None)
        ax.xaxis.set_minor_locator(AutoMinorLocator())
        ax.yaxis.set_minor_locator(AutoMinorLocator())
        ax.grid(which="major")
        ax.grid(which="minor", axis="x", linestyle=":", alpha=0.3)
        ax.grid(which="minor", axis="y", linestyle=":", alpha=0.3)

    plt.tight_layout()
    plt.savefig(f"pdf/results_{DATAKEY}_{METRIC}.pdf")

    fig.suptitle(f"{METRIC} on the {DATAKEY} dataset")
    plt.tight_layout()
    plt.show()

# %%
cache.clear_all()
